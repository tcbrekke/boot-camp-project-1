# %%
import os
import pandas as pd
import numpy as np

# %%
chi_csv = os.path.join("resources", "chi-data.csv")
chi_df = pd.read_csv(chi_csv)

# %%
list(chi_df)
# Out:
# ['id',
#  'Case Number',
#  'Date',
#  'Block',
#  'IUCR',
#  'Primary Type',
#  'Description',
#  'Location Description',
#  'Arrest',
#  'Domestic',
#  'Beat',
#  'District',
#  'Ward',
#  'Community Area',
#  'FBI Code',
#  'X Coordinate',
#  'Y Coordinate',
#  'Year',
#  'Updated On',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
chi_df = chi_df[chi_df['Year'] < 2017] 
chi_df = chi_df[chi_df['Year'] > 2009]
chi_df.reset_index(inplace=True)

chi_data_reclassed_df = chi_df[['Date','Primary Type','Description','Location Description','Year','Latitude','Longitude']]
chi_data_reclassed_df.reset_index(inplace=True)

# %%
len(chi_df)
# Out:
# 2171823

# %%
chi_data_reclassed_df = chi_df[['Date','Primary Type','Description','Location Description','Year','Latitude','Longitude']]
chi_data_reclassed_df


#for i in range(i,len(chi_df['Primary Type']))
counter = 0

for i in range(0,100):
    if chi_df.loc[i, 'Primary Type'] == "CRIM SEXUAL ASSAULT":
        chi_data_reclassed_df.loc['Standard Crime Labels'] = 'Sexual Assault/Rape'  
    else: 
        chi_df.loc[i, 'Standard Crime Labels'] = 'n/a'
        
        
    counter = counter + 1
    if counter % 100 == 0:
        print(f"Processed {counter} records")
# Out:
# Processed 100 records

# %%
def add_standard_label(category, secondary_categories=None, new_label=None):
    if chi_df.loc['Primary Type'] == category:
        if secondary_categories is not None:
            if secondary_categories in chi_df.loc['Description']:
                chi_df.loc['Standard Crime Labels'] = new_label
                print('Label Applied')
        else:
            chi_data_reclassed_df.loc['Standard Crime Labels'] = new_label

# %%
chi_df.head(50)
# Out:
#           id Case Number                    Date  \
# 0   10000092    HY189866  03/18/2015 07:44:00 PM
# 1   10000094    HY190059  03/18/2015 11:00:00 PM
# 2   10000095    HY190052  03/18/2015 10:45:00 PM
# 3   10000096    HY190054  03/18/2015 10:30:00 PM
# 4   10000097    HY189976  03/18/2015 09:00:00 PM
# 5   10000098    HY190032  03/18/2015 10:00:00 PM
# 6   10000099    HY190047  03/18/2015 11:00:00 PM
# 7   10000100    HY189988  03/18/2015 09:35:00 PM
# 8   10000101    HY190020  03/18/2015 10:09:00 PM
# 9   10000104    HY189964  03/18/2015 09:25:00 PM
# 10  10000105    HY189984  03/18/2015 09:30:00 PM
# 11  10000108    HY189719  03/15/2015 04:10:00 PM
# 12  10000109    HY189966  03/18/2015 09:14:00 PM
# 13  10000110    HY190056  03/18/2015 10:50:00 PM
# 14  10000111    HY190019  03/18/2015 10:31:00 PM
# 15  10000112    HY189725  03/18/2015 12:55:00 PM
# 16  10000114    HY190071  03/18/2015 08:00:00 PM
# 17  10000115    HY190036  03/18/2015 09:00:00 PM
# ...

# %%
#Relabeling loop - slow, but faster than reclassing the entire set one type of crime at a time

counter = 0
for i in range(len(chi_df)):
    if chi_df.loc[i, 'Primary Type'] == ('BATTERY' or 'ASSAULT'):
        if "DOMESTIC" in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Domestic Violence'
        else:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Assault/Battery'
    elif chi_df.loc[i, 'Primary Type'] == 'OFFENSE INVOLVING CHILDREN':
        if 'SEX' in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Child Sexual Abuse'
        elif 'PORNOGRAPHY' in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Child Pornography'
        else:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Child Abuse - Non-Sexual'
    elif chi_df.loc[i, 'Primary Type'] == 'HOMICIDE':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Homicide'
    elif chi_df.loc[i, 'Primary Type'] == 'CRIM SEXUAL ASSAULT':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Sexual Assault/Rape'
    elif chi_df.loc[i, 'Primary Type'] == 'ARSON':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Arson'
    elif chi_df.loc[i, 'Primary Type'] == 'ROBBERY':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Robbery'
    elif chi_df.loc[i, 'Primary Type'] == 'STALKING':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Stalking/Menacing'
    elif chi_df.loc[i, 'Primary Type'] == 'KIDNAPPING':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Kidnapping/False Imprisonment'
    elif chi_df.loc[i, 'Primary Type'] == 'BURGLARY':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Burglary'
    elif chi_df.loc[i, 'Primary Type'] == 'CRIMINAL DAMAGE':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Vandalism'
    elif chi_df.loc[i, 'Primary Type'] == 'WEAPONS VIOLATION':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Weapons Offense'
    elif chi_df.loc[i, 'Primary Type'] == 'PROSTITUTION':
        if ('PIMPING' or 'PANDERING' or 'KEEP PREMISE') in chi_df.loc[i, 'Description']:
            if 'JUV' in chi_df.loc[i, 'Description']:
                chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Child Sexual Abuse'
            else:
                chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Human Trafficking'
        elif 'JUV' in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Child Sexual Abuse'
        else:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Prostitution'
    elif chi_df.loc[i, 'Primary Type'] == 'PUBLIC INDECENCY':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Unlawful Sexual Conduct'
    elif chi_df.loc[i, 'Primary Type'] == 'RITUALISM':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Assault/Battery'
    elif chi_df.loc[i, 'Primary Type'] == 'PUBLIC PEACE VIOLATION':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Disorderly Conduct/Disturbing the Peace'
    elif chi_df.loc[i, 'Primary Type'] == 'THEFT':
        if ('ID' or 'IDENTITY') in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Identity Theft'
        else:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'General Theft/Shoplifting'
    elif chi_df.loc[i, 'Primary Type'] == 'MOTOR VEHICLE THEFT':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Auto Theft'
    elif chi_df.loc[i, 'Primary Type'] == 'SEX OFFENSE':
        if ('SOLICITATION') in chi_df.loc[i, 'Description']:
            if ('CHILD') in chi_df.loc[i, 'Description']:
                chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Child Sexual Abuse'
            else: 
                chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Prostitution'
        elif ('CHILD') in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Child Sexual Abuse'
        elif ('BIGAMY' or 'BIGAMIST') in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Fraud'
        else:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Unlawful Sexual Conduct'
    elif chi_df.loc[i, 'Primary Type'] == 'OTHER OFFENSE':
        if ('ANIMAL') in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Animal Abuse'
        elif ('TELEPHONE' or 'ELECTRONIC') in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Menacing'
        elif ('HIGHER EDUCATION') in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Disorderly Conduct/Disturbing the Peace'
        elif ('BURGLARY') in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Burglary'
        elif ('VEHICLE' or 'VEHICULAR') in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Vehicular Offense'
        elif ('FIREARM' or 'GUN' or 'WEAPON') in chi_df.loc[i, 'Description']:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Weapons Offense'
        else:
            chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Uncategorized'
    elif chi_df.loc[i, 'Primary Type'] == 'INTERFERENCE WITH PUBLIC OFFICER':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Interference/Assault on a Public Officer'
    elif chi_df.loc[i, 'Primary Type'] == 'INTIMIDATION':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Menacing'
    elif chi_df.loc[i, 'Primary Type'] == 'NARCOTICS':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Narcotics Offense'
    elif chi_df.loc[i, 'Primary Type'] == 'LIQUOR LAW VIOLATION':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Liquor Law Violation'
    elif chi_df.loc[i, 'Primary Type'] == 'GAMBLING':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Bunco/Scam/Gambling'
    elif chi_df.loc[i, 'Primary Type'] == 'DECEPTIVE PRACTICE':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Fraud'
    elif chi_df.loc[i, 'Primary Type'] == 'MOTOR VEHICLE THEFT':
        chi_data_reclassed_df.loc[i, 'Standard Crime Labels'] = 'Auto Theft'

    counter = counter + 1
    if counter % 1000 == 0:
        print(f"Processed {counter} records")

# %%
#This code works, but is very slow

def standard_label_function(target_df, secondary_df, primary_type, new_classification, description=None):
    counter = 0
    for i in range(len(target_df)):
        if target_df.loc[i, 'Primary Type'] == primary_type:
            if description is not None:
                if description in target_df.loc[i, 'Description']:
                    secondary_df.loc[i, 'Standard Crime Labels'] = new_classification  
            else:
                secondary_df.loc[i, 'Standard Crime Labels'] = new_classification
        else:
            pass

        counter = counter + 1
        if counter % 100 == 0:
            print(f"Processed {counter} records")

# %%
standard_label_function(chi_df, chi_data_reclassed_df, ('BATTERY' or 'ASSAULT'), 'Assault/Battery')
standard_label_function(chi_df, chi_data_reclassed_df, 'BATTERY', 'Domestic Violence', description='DOMESTIC')
standard_label_function(chi_df, chi_data_reclassed_df, 'OFFENSE INVOLVING CHILDREN', 'Child Abuse - Non-Sexual')
standard_label_function(chi_df, chi_data_reclassed_df, 'OFFENSE INVOLVING CHILDREN', 'Child Sexual Abuse', description='SEX')
standard_label_function(chi_df, chi_data_reclassed_df, 'OFFENSE INVOLVING CHILDREN', 'Child Pornography', description ='Pornography')
standard_label_function(chi_df, chi_data_reclassed_df, 'HOMICIDE', 'Homicide')
standard_label_function(chi_df, chi_data_reclassed_df, 'CRIM SEXUAL ASSAULT', 'Sexual Assault/Rape')
standard_label_function(chi_df, chi_data_reclassed_df, 'ARSON', 'Arson')
standard_label_function(chi_df, chi_data_reclassed_df, 'ROBBERY', 'Robbery')
standard_label_function(chi_df, chi_data_reclassed_df, 'STALKING', 'Menacing')
standard_label_function(chi_df, chi_data_reclassed_df, 'THEFT', 'Purse Snatching/Pickpocketing', description = ('POCKET-PICKING' | 'PURSE-SNATCHING'))
standard_label_function(chi_df, chi_data_reclassed_df, 'KIDNAPPING', 'Kidnapping')
standard_label_function(chi_df, chi_data_reclassed_df, 'BURGLARY', 'Burglary')
standard_label_function(chi_df, chi_data_reclassed_df, 'CRIMINAL DAMAGE', 'Vandalism')
standard_label_function(chi_df, chi_data_reclassed_df, 'WEAPONS VIOLATION', 'Weapons Offense')
standard_label_function(chi_df, chi_data_reclassed_df, 'PROSTITUTION', 'Prostitution')
standard_label_function(chi_df, chi_data_reclassed_df, 'PROSTITUTION', 'Human Trafficking', description = ('PIMPING' | 'PANDERING' | 'KEEP PREMISE'))
standard_label_function(chi_df, chi_data_reclassed_df, 'PROSTITUTION', 'Child Sexual Abuse', description = ('JUV'))
standard_label_function(chi_df, chi_data_reclassed_df, 'PUBLIC INDECENCY', 'Unlawful Sexual Conduct')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-50431a6aab54> in <module>()
# ----> 1 standard_label_function(chi_df, chi_data_reclassed_df, ('BATTERY' or 'ASSAULT'), 'Assault/Battery')
#       2 standard_label_function(chi_df, chi_data_reclassed_df, 'BATTERY', 'Domestic Violence', description='DOMESTIC')
#       3 standard_label_function(chi_df, chi_data_reclassed_df, 'OFFENSE INVOLVING CHILDREN', 'Child Abuse - Non-Sexual')
#       4 standard_label_function(chi_df, chi_data_reclassed_df, 'OFFENSE INVOLVING CHILDREN', 'Child Sexual Abuse', description='SEX')
#       5 standard_label_function(chi_df, chi_data_reclassed_df, 'OFFENSE INVOLVING CHILDREN', 'Child Pornography', description ='Pornography')
#
# NameError: name 'chi_df' is not defined
