# %%
import os
import pandas as pd
import numpy as np

# %%
la_csv = os.path.join("resources", "la-data.csv")
la_df = pd.read_csv(la_csv)

# %%
list(la_df)
la_df['Crime Code Description'].unique()
# Out:
# array(['INTIMATE PARTNER - SIMPLE ASSAULT', 'VEHICLE - STOLEN',
#        'VANDALISM - MISDEAMEANOR ($399 OR UNDER)', 'CRIMINAL HOMICIDE',
#        'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
#        'THEFT PLAIN - PETTY ($950 & UNDER)', 'STALKING',
#        'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#        'BATTERY - SIMPLE ASSAULT',
#        'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)',
#        'DOCUMENT FORGERY / STOLEN FELONY', 'BIKE - STOLEN', 'ROBBERY',
#        'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH 0007=02',
#        'ATTEMPTED ROBBERY', 'RESISTING ARREST', 'TRESPASSING',
#        'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD0036',
#        'COUNTERFEIT', 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'THROWING OBJECT AT MOVING VEHICLE',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $400 & UNDER',
#        'CRIMINAL THREATS - NO WEAPON DISPLAYED',
#        'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114',
# ...

# %%
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['BATTERY - SIMPLE ASSAULT','ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT','OTHER ASSAULT'], 'Assault/Battery')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['INTIMATE PARTNER - SIMPLE ASSAULT',
'INTIMATE PARTNER - AGGRAVATED ASSAULT'], 'Domestic Violence')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['GRAND THEFT / INSURANCE FRAUD',
'GRAND THEFT / INSURANCE FRAUD',
'DOCUMENT FORGERY / STOLEN FELONY',
'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD0036',
'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $400 & UNDER'
'CREDIT CARDS, FRAUD USE ($950.01 & OVER)',
'CREDIT CARDS, FRAUD USE ($950 & UNDER',
'BIGAMY',
'COUNTERFEIT',
'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $400','DEFRAUDING INNKEEPER/THEFT OF SERVICES, $400 & UNDER',
'DOCUMENT WORTHLESS ($200.01 & OVER)',
'DOCUMENT WORTHLESS ($200 & UNDER)',
'PETTY THEFT - AUTO REPAIR',
'GRAND THEFT / AUTO REPAIR','CREDIT CARDS, FRAUD USE ($950.01 & OVER)'], 'Fraud')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER',
'BATTERY ON A FIREFIGHTER','BATTERY POLICE (SIMPLE)'], 'Assault on a Public Servant')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['VEHICLE - STOLEN',
'DRIVING WITHOUT OWNER CONSENT (DWOC)',
'VEHICLE - ATTEMPT STOLEN'], 'Auto Theft')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['VANDALISM - MISDEAMEANOR ($399 OR UNDER)',
'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114',
'TELEPHONE PROPERTY - DAMAGE'], 'Vandalism')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace('BOAT - STOLEN', 'Boat Theft')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['VANDALISM - MISDEAMEANOR ($399 OR UNDER)',
'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114',
'TELEPHONE PROPERTY - DAMAGE'], 'Vandalism')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['BURGLARY FROM VEHICLE',
'BURGLARY FROM VEHICLE, ATTEMPTED',
'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)','THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)','THEFT FROM MOTOR VEHICLE - ATTEMPT'], 'Theft From Vehicle')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)',
'DISHONEST EMPLOYEE - PETTY THEFT',
'DISHONEST EMPLOYEE - GRAND THEFT',
'DISHONEST EMPLOYEE ATTEMPTED THEFT',
'TILL TAP - ATTEMPT',
'TILL TAP - GRAND THEFT ($950.01 & OVER)',
'TILL TAP - PETTY ($950 & UNDER)'], 'Workplace Offense')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['ROBBERY',
'ATTEMPTED ROBBERY'], 'Robbery')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['BUNCO, GRAND THEFT',
'BUNCO, PETTY THEFT',
'BUNCO, ATTEMPT'], 'Bunco/Scam')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['KIDNAPPING',
'KIDNAPPING - GRAND ATTEMPT',
'CHILD STEALING','FALSE IMPRISONMENT',], 'Kidnapping')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['LEWD/LASCIVIOUS ACTS WITH CHILD',
'CHILD PORNOGRAPHY',
'CHILD ANNOYING (17YRS & UNDER)',
'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)0060'], 'Child Sexual Abuse')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
'CHILD NEGLECT (SEE 300 W.I.C.)',
'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT',
'CHILD ABANDONMENT','CONTRIBUTING',],'Child Abuse - Non-Sexual')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['THEFT, PERSON',
'PICKPOCKET, ATTEMPT',
'PICKPOCKET',
'THEFT FROM PERSON - ATTEMPT',
'PURSE SNATCHING - ATTEMPT',
'PURSE SNATCHING','DRUNK ROLL',
'DRUNK ROLL - ATTEMPT'],'Purse Snatching/Pickpocketing')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['CRIMINAL THREATS - NO WEAPON DISPLAYED',
'THREATENING PHONE CALLS/LETTERS',
'STALKING'],'Menacing')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['CRUELTY TO ANIMALS'],'Animal Abuse')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['RAPE, ATTEMPTED',
'SEXUAL PENTRATION WITH A FOREIGN OBJECT',
'BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM0065',
'INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)',
'SEXUAL PENETRATION W/FOREIGN OBJECT',
'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
'LEWD CONDUCT',
'ORAL COPULATION',
'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH 0007=02','BATTERY WITH SEXUAL CONTACT','RAPE, FORCIBLE',
'INDECENT EXPOSURE',
'LETTERS, LEWD','SEX, UNLAWFUL','SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ0059'],'Unlawful Sexual Conduct')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['HUMAN TRAFFICKING - COMMERCIAL SEX ACTS',
'HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE',
'PANDERING',
'PIMPING',],'Human Trafficking')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['FIREARMS RESTRAINING ORDER (FIREARMS RO)',
'SHOTS FIRED AT INHABITED DWELLING',
'BRANDISH WEAPON',
'WEAPONS POSSESSION/BOMBING',
'REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)0132',
'DISCHARGE FIREARMS/SHOTS FIRED',
'SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT',],'Weapons Offense')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['PROWLER',
'DISRUPT SCHOOL',
'TRESPASSING','PEEPING TOM',],'Trespassing')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['BIKE - STOLEN',
'BIKE - ATTEMPTED STOLEN'],'Bicycle Theft')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['FAILURE TO DISPERSE',
'INCITING A RIOT',
'BLOCKING DOOR INDUCTION CENTER'],'Unlawful Assembly')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['UNAUTHORIZED COMPUTER ACCESS'],'Cybercrime')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
'THEFT PLAIN - PETTY ($950 & UNDER)',
'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD0036',
'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
'THEFT, COIN MACHINE - PETTY ($950 & UNDER)',
'THEFT, COIN MACHINE - GRAND ($950.01 & OVER)',
'THEFT, COIN MACHINE - ATTEMPT',
'THEFT PLAIN - ATTEMPT','SHOPLIFTING - ATTEMPT',],'General Theft/Shoplifting')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['RECKLESS DRIVING',
'THROWING OBJECT AT MOVING VEHICLE','FAILURE TO YIELD'],'Vehicular Offense')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['BRIBERY'],'Bribery')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['TRAIN WRECKING',],'Train Wrecking')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['ARSON',],'Arson')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['CONSPIRACY',],'Conspiracy')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['VIOLATION OF COURT ORDER',
'VIOLATION OF TEMPORARY RESTRAINING ORDER',
'CONTEMPT OF COURT',
'VIOLATION OF RESTRAINING ORDER',],'Legal System Violation')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['OTHER MISCELLANEOUS CRIME',], 'Uncategorized')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['DRUGS, TO A MINOR',],'Narcotics Offense')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['MANSLAUGHTER, NEGLIGENT',
'CRIMINAL HOMICIDE',
'LYNCHING - ATTEMPTED',
'LYNCHING',],'Homicide')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['BURGLARY, ATTEMPTED',
'BURGLARY',],'Burglary')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['RESISTING ARREST',
'DISTURBING THE PEACE',
'BOMB SCARE',],'Disorderly Conduct/Disturbing The Peace')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['THEFT OF IDENTITY'],'Identity Theft')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace('EXTORTION','Extortion')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace('ILLEGAL DUMPING','Illegal Dumping')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace('ABORTION/ILLEGAL','Illegal Abortion')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace('FALSE POLICE REPORT','False Police Report')

# %%
la_df['Crime Code Description'].value_counts()
# Out:
# Assault/Battery                            232270
# Theft From Vehicle                         230025
# General Theft/Shoplifting                  165188
# Vandalism                                  162931
# Auto Theft                                 134821
# Burglary                                   134003
# Identity Theft                             107534
# Domestic Violence                          102866
# Fraud                                       84566
# Robbery                                     78352
# Menacing                                    51933
# Unlawful Sexual Conduct                     47275
# Legal System Violation                      35849
# Trespassing                                 17720
# Uncategorized                               17461
# Weapons Offense                             15812
# Child Abuse - Non-Sexual                    13701
# Purse Snatching/Pickpocketing               13463
# Child Sexual Abuse                          11379
# ...

# %%
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER',
'BATTERY ON A FIREFIGHTER', 'Assault on a Public Servant'])
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['VEHICLE - STOLEN',
'DRIVING WITHOUT OWNER CONSENT (DWOC)',
'VEHICLE - ATTEMPT STOLEN'], 'Auto Theft')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace(['VANDALISM - MISDEAMEANOR ($399 OR UNDER)',
'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114',
'TELEPHONE PROPERTY - DAMAGE'], 'Vandalism')
la_df['Crime Code Description'] = la_df['Crime Code Description'].replace('BOAT - STOLEN', 'Boat Theft')

# %%
la_df.to_csv(os.path.join("resources","la_csv_relabeled.csv"))
